# %%
name="sameer"
age=21
height=5.4
isstudent=True
print(type(name),type(age), type(height), type(isstudent))
# Out:
# <class 'str'> <class 'int'> <class 'float'> <class 'bool'>

# %%
marks=[10,20,25,23]
print(marks)
print(marks[0])
print(len(marks))
# Out:
# [10, 20, 25, 23]
# 10
# 4

# %%
student={"name": "sameer", "age": 21, "marks":[10,20,25,23]}
print(student["name"])
print(student["marks"])
# Out:
# sameer
# [10, 20, 25, 23]

# %%
for m in marks:
    print(m)
# Out:
# 1
# 2
# 3

# %%
def avg(num):
    return sum(num)/len(num)
print(avg(marks))
# Out:
# 2.0

# %%
def p(num):
    if(sum(num)/len(num) >=50):
        return "pass"
    else:
        return "fail"
print(p(marks))
# Out:
# fail
